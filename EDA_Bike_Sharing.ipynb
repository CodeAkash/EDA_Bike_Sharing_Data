# %% [markdown]
# # Problem Statement
#
# With environmental issues and health becoming trending topics, usage of bicycles as a mode of transportation has gained traction in recent years. To encourage bike usage, cities across the world have successfully rolled out bike sharing programs. Under such schemes, riders can rent bicycles using manual/ automated kiosks spread across the city for defined periods. In most cases, riders can pick up bikes from one location and return them to any other designated place. The bike sharing platforms from across the world are hotspots of all sorts of data, ranging from travel time, start and end location, demographics of riders, and so on. This data along with alternate sources of information such as weather, traffic, terrain, and so on makes it an attractive proposition for different research areas. The Capital Bike Sharing dataset contains information related to one such bike sharing program underway in Washington DC. Given this augmented (bike sharing details along with weather information) dataset, can we forecast bike rental demand for this program?

# %% [markdown]
# # Exploratory Data Analysis

# %%
import pandas as pd

df=pd.read_csv('hour.csv')

# %%
df.head()
# Out:
#    instant      dteday  season  yr  mnth  hr  holiday  weekday  workingday  \
# 0        1  2011-01-01       1   0     1   0        0        6           0
# 1        2  2011-01-01       1   0     1   1        0        6           0
# 2        3  2011-01-01       1   0     1   2        0        6           0
# 3        4  2011-01-01       1   0     1   3        0        6           0
# 4        5  2011-01-01       1   0     1   4        0        6           0
#
#    weathersit  temp   atemp   hum  windspeed  casual  registered  cnt
# 0           1  0.24  0.2879  0.81        0.0       3          13   16
# 1           1  0.22  0.2727  0.80        0.0       8          32   40
# 2           1  0.22  0.2727  0.80        0.0       5          27   32
# 3           1  0.24  0.2879  0.75        0.0       3          10   13
# 4           1  0.24  0.2879  0.75        0.0       0           1    1

# %%
df.describe()
# Out:
#           instant        season            yr          mnth            hr  \
# count  17379.0000  17379.000000  17379.000000  17379.000000  17379.000000
# mean    8690.0000      2.501640      0.502561      6.537775     11.546752
# std     5017.0295      1.106918      0.500008      3.438776      6.914405
# min        1.0000      1.000000      0.000000      1.000000      0.000000
# 25%     4345.5000      2.000000      0.000000      4.000000      6.000000
# 50%     8690.0000      3.000000      1.000000      7.000000     12.000000
# 75%    13034.5000      3.000000      1.000000     10.000000     18.000000
# max    17379.0000      4.000000      1.000000     12.000000     23.000000
#
#             holiday       weekday    workingday    weathersit          temp  \
# count  17379.000000  17379.000000  17379.000000  17379.000000  17379.000000
# mean       0.028770      3.003683      0.682721      1.425283      0.496987
# ...

# %%
df.dtypes
# Out:
# instant         int64
# dteday         object
# season          int64
# yr              int64
# mnth            int64
# hr              int64
# holiday         int64
# weekday         int64
# workingday      int64
# weathersit      int64
# temp          float64
# atemp         float64
# hum           float64
# windspeed     float64
# casual          int64
# registered      int64
# cnt             int64
# dtype: object

# %%
df.rename(columns = {'instant':'rec_id',
                      'dteday':'datetime',
                      'holiday':'is_holiday',
                      'workingday':'is_workingday',
                      'weathersit':'weather_condition',
                      'hum':'humidity',
                      'mnth':'month',
                      'cnt':'total_count',
                      'hr':'hour',
                      'yr':'year'},inplace = True)

# %%
# date time conversion
df['datetime']=pd.to_datetime(df.datetime)

# %%
#categorical
df['season'] = df.season.astype('category')
df['is_holiday'] = df.is_holiday.astype('category')
df['weekday'] = df.weekday.astype('category')
df['weather_condition'] = df.weather_condition.astype('category')
df['is_workingday'] = df.is_workingday.astype('category')
df['month'] = df.month.astype('category')
df['year'] = df.year.astype('category')
df['hour'] = df.hour.astype('category')
df.dtypes
# Out:
# rec_id                        int64
# datetime             datetime64[ns]
# season                     category
# year                       category
# month                      category
# hour                       category
# is_holiday                 category
# weekday                    category
# is_workingday              category
# weather_condition          category
# temp                        float64
# atemp                       float64
# humidity                    float64
# windspeed                   float64
# casual                        int64
# registered                    int64
# total_count                   int64
# dtype: object

# %% [markdown]
# # Visualize Attributes, Trends and Relationships

# %%
import seaborn as sns
import matplotlib.pyplot as plt

fig,ax = plt.subplots(figsize=(15,5))
sns.pointplot(data=df[['hour','total_count','season']],x='hour',y='total_count',hue='season',ax=ax)
ax.set(title = 'Season wise hourly distribution of counts')
# Out:
# [Text(0.5, 1.0, 'Season wise hourly distribution of counts')]

# %%
seasons_dict = {1:'spring',2:"summer",3:'fall',4: 'winter'}

#replacing values of season column
df['season'] = df['season'].map(seasons_dict)

# %%
fig,ax = plt.subplots(figsize = (15,5))
sns.pointplot(data = df[['hour','total_count','season']],x='hour',y='total_count',hue='season',ax=ax)
ax.set(title = 'Season wise hourly distribution of counts')
# Out:
# [Text(0.5, 1.0, 'Season wise hourly distribution of counts')]

# %%
fig,ax = plt.subplots(figsize = (15,5))
sns.pointplot(data=df[['hour','total_count','weekday']],x='hour',y='total_count',hue='weekday',ax=ax)
ax.set(title="Weekday wise hourly distribution of counts")
# Out:
# [Text(0.5, 1.0, 'Weekday wise hourly distribution of counts')]

# %%
fig,ax = plt.subplots(figsize=(15,5))
sns.pointplot(data = df[['hour','total_count']], x= 'hour', y = 'total_count', ax = ax)
ax.set(title = 'Point Plot for hourly distribution of counts over months')
# Out:
# [Text(0.5, 1.0, 'Point Plot for hourly distribution of counts over months')]

# %%
fig,ax = plt.subplots(figsize=(15,5))
sns.boxplot(data = df[['hour','total_count']], x= 'hour', y = 'total_count', ax = ax)
ax.set(title = 'Box Plot for hourly distribution of counts over months')
# Out:
# [Text(0.5, 1.0, 'Box Plot for hourly distribution of counts over months')]

# %%
df['year'].unique()
# Out:
# [0, 1]
# Categories (2, int64): [0, 1]

# %%
df.total_count.dtype
# Out:
# dtype('int64')

# %%
df.head()
# Out:
#    rec_id   datetime  season year month hour is_holiday weekday is_workingday  \
# 0       1 2011-01-01  spring    0     1    0          0       6             0
# 1       2 2011-01-01  spring    0     1    1          0       6             0
# 2       3 2011-01-01  spring    0     1    2          0       6             0
# 3       4 2011-01-01  spring    0     1    3          0       6             0
# 4       5 2011-01-01  spring    0     1    4          0       6             0
#
#   weather_condition  temp   atemp  humidity  windspeed  casual  registered  \
# 0                 1  0.24  0.2879      0.81        0.0       3          13
# 1                 1  0.22  0.2727      0.80        0.0       8          32
# 2                 1  0.22  0.2727      0.80        0.0       5          27
# 3                 1  0.24  0.2879      0.75        0.0       3          10
# 4                 1  0.24  0.2879      0.75        0.0       0           1
#
#    total_count
# 0           16
# ...

# %%
fig,ax = plt.subplots(figsize = (15,5))
sns.barplot(data = df[['year','total_count']], x = 'year', y = 'total_count', ax = ax)
ax.set(title = 'Yearly distribution of counts')
# Out:
# [Text(0.5, 1.0, 'Yearly distribution of counts')]

# %%
year_0_counts = df.loc[df['year'] == 0, 'total_count'].sum()
year_1_counts = df.loc[df['year'] == 1, 'total_count'].sum()

year_0_counts,year_1_counts
# Out:
# (1243103, 2049576)

# %%
sns.violinplot(data = df[['year','total_count']], x = 'year', y = 'total_count')
# Out:
# <AxesSubplot:xlabel='year', ylabel='total_count'>

# %% [markdown]
# While exploring and learning about any dataset, it is imperative that we check for extreme and unlikely
# values. Though we handle missing and incorrect information while preprocessing the dataset, outliers are
# usually caught during EDA. Outliers can severely and adversely impact the downstream steps like modeling
# and the results. We usually utilize boxplots to check for outliers in the data.

# %%
fig, (ax1,ax2) = plt.subplots(figsize = (15,5),ncols=2)
sns.boxplot(data = df[['total_count', 'casual', 'registered']], ax = ax1)
sns.boxplot(data = df[['temp','windspeed']], ax = ax2)
# Out:
# <AxesSubplot:>

# %% [markdown]
# Correlation helps us understand relationships between different attributes of the data.

# %%
import numpy as np

# %%
corrMatt = df[["temp","atemp","humidity","windspeed","casual","registered","total_count"]].corr()
mask = np.array(corrMatt)
mask[np.tril_indices_from(mask)]=False
sns.heatmap(corrMatt,mask = mask,
          vmax = 0.8, square = True, annot = True)
# Out:
# <AxesSubplot:>

# %% [markdown]
# Correlation between temp and atemp is very high (as expected)
#
# Same is te case with registered-total_count and casual-total_count
#
# Windspeed to humidity has negative correlation
#
# Overall correlational statistics are not very high.

# %% [markdown]
# ## Working Day Vs Holiday Distribution

# %%
fig, (ax1,ax2) = plt.subplots(figsize = (15,5),ncols = 2)
sns.barplot(data = df, x = 'is_holiday', y = 'total_count', hue = 'season', ax = ax1)
sns.barplot(data = df, x= 'is_workingday', y = 'total_count', hue = 'season', ax = ax2)
# Out:
# <AxesSubplot:xlabel='is_workingday', ylabel='total_count'>

# %%
df_col_list = ['month','weekday','total_count']
plot_col_list= ['month','total_count']
spring_df = df[df.season=="spring"][df_col_list]
summer_df = df[df.season=="summer"][df_col_list]
fall_df =   df[df.season=="fall"][df_col_list]
winter_df = df[df.season=="winter"][df_col_list]

fig,ax= plt.subplots(figsize = (15,5),nrows=2,ncols=2)
sns.barplot(data=spring_df[plot_col_list],x="month",y="total_count",ax=ax[0][0],)
ax[0][0].set(title="Spring")

sns.barplot(data=summer_df[plot_col_list],x="month",y="total_count",ax=ax[0][1])
ax[0][1].set(title="Summer")

sns.barplot(data=fall_df[plot_col_list],x="month",y="total_count",ax=ax[1][0])
ax[1][0].set(title="Fall")

sns.barplot(data=winter_df[plot_col_list],x="month",y="total_count",ax=ax[1][1])  
ax[1][1].set(title="Winter")
# Out:
# [Text(0.5, 1.0, 'Winter')]
